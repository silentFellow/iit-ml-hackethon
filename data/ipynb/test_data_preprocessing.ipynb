# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# creating dataframe
df = pd.read_csv("../csv/raw_test_data.csv")
df.head(1)
# Out:
#      Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0  15001  2021-05-17  8:00 AM            Meghalaya                       -
#
#   ConfirmedForeignNational  Cured  Confirmed  OxygenTanks  \
# 0                        -  18478      23332          191
#
#    PopulationDensityPerSqKm
# 0                       514

# %%
# changing values of column names to lowercase
cols = df.columns
lower_cols = []
for i in range(len(cols)):
    lower_cols.append(cols[i].lower())
df.columns = lower_cols
df.head(1)
# Out:
#      sno        date     time state/unionterritory confirmedindiannational  \
# 0  15001  2021-05-17  8:00 AM            Meghalaya                       -
#
#   confirmedforeignnational  cured  confirmed  oxygentanks  \
# 0                        -  18478      23332          191
#
#    populationdensitypersqkm
# 0                       514

# %%
# processing date
df["date"] = pd.to_datetime(df["date"])
df["day"] = df["date"].dt.day
df["month"] = df["date"].dt.month
df["year"] = df["date"].dt.year
df["week"] = df["date"].dt.isocalendar().week
df["weekday_number"] = df["date"].dt.weekday

# processing time
def process_time(df):
    total = df["time"].split(" ")
    time = total[0]
    am_pm = total[1]

    df["hour"] = time.split(":")[0]
    df["minute"] = time.split(":")[1]
    df["am_pm"] = 0 if am_pm == "AM" else 1

    return df

df = df.apply(process_time, axis=1)

df.head(1)
# Out:
#      sno       date     time state/unionterritory confirmedindiannational  \
# 0  15001 2021-05-17  8:00 AM            Meghalaya                       -
#
#   confirmedforeignnational  cured  confirmed  oxygentanks  \
# 0                        -  18478      23332          191
#
#    populationdensitypersqkm  day  month  year  week  weekday_number hour  \
# 0                       514   17      5  2021    20               0    8
#
#   minute  am_pm
# 0     00      0

# %%
# dropping unwanted column
df.drop(columns=["sno", "date", "time", "confirmedindiannational", "confirmedforeignnational"], axis=1, inplace=True)
df.head(1)
# Out:
#   state/unionterritory  cured  confirmed  oxygentanks  \
# 0            Meghalaya  18478      23332          191
#
#    populationdensitypersqkm  day  month  year  week  weekday_number hour  \
# 0                       514   17      5  2021    20               0    8
#
#   minute  am_pm
# 0     00      0

# %%
# Label envode state
le = LabelEncoder()
df["state/unionterritory"] = le.fit_transform(df["state/unionterritory"])
df.head(1)
# Out:
#    state/unionterritory  cured  confirmed  oxygentanks  \
# 0                    28  18478      23332          191
#
#    populationdensitypersqkm  day  month  year  week  weekday_number hour  \
# 0                       514   17      5  2021    20               0    8
#
#   minute  am_pm
# 0     00      0

# %%
# standarization
ss = StandardScaler()
cols = ["cured", "oxygentanks", "confirmed", "populationdensitypersqkm"]

for i in cols:
    df[i] = ss.fit_transform(df[[i]])

df.head(3)
# Out:
#    state/unionterritory     cured  confirmed  oxygentanks  \
# 0                    28 -0.686890  -0.683871    -1.646990
# 1                    29 -0.697378  -0.696178    -1.328390
# 2                    30 -0.691080  -0.688331     1.713893
#
#    populationdensitypersqkm  day  month  year  week  weekday_number hour  \
# 0                  0.051243   17      5  2021    20               0    8
# 1                  0.297784   17      5  2021    20               0    8
# 2                  0.368225   17      5  2021    20               0    8
#
#   minute  am_pm
# 0     00      0
# 1     00      0
# 2     00      0

# %%
# export as preprocessed data
df.to_csv("../csv/preprocessed_test_data.csv", index=False, mode="w")
